# %% [markdown]
# All this below is what it would look in Google Colab
# File paths and locations same thing (the paths as in Google Colab)

# %%
# %pip install roboflow
# %pip install ultralytics

# %% [markdown]
# Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Pyq8Fx6JmmQTa3dc79wH")
project = rf.workspace("pickleball-ball-detection").project("pickleball-detector")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pickleball-Detector-6 in yolov5pytorch:: 100%|██████████| 6084/6084 [05:29<00:00, 18.48it/s]

# %%
# shutil module (shell utilities) provides a high-level interface for powerful file operations, 
#   automating common tasks like copying, moving, and removing files and directories
import shutil

# Need to move the information sets because that is where they are said to be in the data.yaml file
shutil.move("pickleball-detector-6/train", 'pickleball-detector-6/pickleball-detector-6/train')
shutil.move("pickleball-detector-6/test", 'pickleball-detector-6/pickleball-detector-6/test')
shutil.move("pickleball-detector-6/valid", 'pickleball-detector-6/pickleball-detector-6/valid')
# Out:
# 'pickleball-detector-6/pickleball-detector-6/valid'
