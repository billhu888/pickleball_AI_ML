# %% [markdown]
# All this below is what it would look in Google Colab
# File paths and locations same thing (the paths as in Google Colab)

# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Pyq8Fx6JmmQTa3dc79wH")
project = rf.workspace("xuann-bacc-ujr91").project("pickle-court-keypoints-nluo7")
version = project.version(10)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pickle-court-keypoints-10 in yolov5pytorch::   0%|          | 7/2080 [00:00<00:10, 206.64it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 5
#       3 project = rf.workspace("xuann-bacc-ujr91").project("pickle-court-keypoints-nluo7")
#       4 version = project.version(10)
# ----> 5 dataset = version.download("yolov5")
#
# File c:\Users\Willi\anaconda3\Lib\site-packages\roboflow\core\version.py:233, in Version.download(self, model_format, location, overwrite)
#     230             response.raise_for_status()
#     232 self.__download_zip(link, location, model_format)
# --> 233 self.__extract_zip(location, model_format)
#     234 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
# ...

# %%
import shutil
# Need to move the information sets because that is where they are said to be in the data.yaml file
shutil.move("training/pickle-court-keypoints-10/train", 'training/pickle-court-keypoints-10/training/pickle-court-keypoints-10/train')
shutil.move("training/pickle-court-keypoints-10/test", 'training/pickle-court-keypoints-10/training/pickle-court-keypoints-10/test')
shutil.move("training/pickle-court-keypoints-10/valid", 'training/pickle-court-keypoints-10/training/pickle-court-keypoints-10/valid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Willi\anaconda3\Lib\shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'training/pickle-court-keypoints-10/train' -> 'training/pickle-court-keypoints-10/training/pickle-court-keypoints-10/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import shutil
#       2 # Need to move the information sets because that is where they are said to be in the data.yaml file
# ----> 3 shutil.move("training/pickle-court-keypoints-10/train", 'training/pickle-court-keypoints-10/training/pickle-court-keypoints-10/train')
# ...
